# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Examples.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>

# %% [markdown]
# # Examples: Python modules

# %% [markdown]
# This notebook accompanies the walk-through video on Python modules and packages and also contains a few additional examples on how we can use modules.

# %% [markdown]
# ## Learning objectives
# In this train, we will learn how to:
# - Write a module and import all or specific objects from a module.
# - Import modules using an alias name and explore the use of built-in modules.
#
#
# ## Outline
# To do this, we will:
# - Define the importance of modules and packages in programming.
# - Review the syntax and conventions for importing modules.
# - Consider the use of built-in Python modules.

# %% [markdown]
# ## Introduction
# Modular programming is a style of programming that promotes code reusability, allowing us to generate single pieces of code which can be used in multiple parts of a project – thus saving time and resources. The resulting code can be simpler to understand and maintain since components can be considered in isolation. In Python, **modularisation** is implemented using functions, modules, and packages.
#
# A **module** is a file consisting of Python code. A module can define functions, classes, variables, and runnable code. These modules can be imported and referenced from other Python code. A **Python package** (also referred to as a library) is a collection of hierarchically structured directories of Python code consisting of sub-packages and modules.
#
# Modules and packages are two mechanisms that facilitate modular programming.
#
# ## Why modularisation?
#
# * **Reusability**: Eliminates the need to write new code, as functionality defined in a single module can be easily reused.
#
#
# * **Simplicity**: Modules generally tend to focus on a selected area of the problem which is usually small, rather than focusing on the entire problem at hand. Integrating the use of selected modules will result in systematically dealing with each small problem in the code, making development easier and less error-prone.
#
#
# * **Maintainability**: Modules in Python are often designed to be self-supporting. In this sense, one module does not depend entirely upon other modules to work. Therefore, it is unlikely that modifying a single module of a program will affect other parts of the program. This allows a team of many programmers or data scientists to work collaboratively on a large application.

# %% [markdown]
# ## Working with modules
#
# ### Creating modules
# Creating a module is as simple as saving a Python script with functions, classes, variables and running code. The file name is the module name with the suffix `.py` appended.
#
# ### Importing modules
# We can access this module and its elements from a different Python file by using the `import` statement.
# * We can import a single module/package:
#
#     ```python
#     import <module_name>
#     ```
#
# * Import multiple modules using individual import statements:
#
#     ```python
#     import <module_1_name>
#     import <module_2_name>
#     import <module_3_name>
#     ...```
#
#
#
# The same rules apply when dealing with packages. We can import specific modules within a package by using dot notation. For this to work, we have to structure packages and modules in a way that reflects the hierarchy in the package directory.
#
#    ```python
#     import <package_name>.<sub_package_name>.<module_name>.<...>
#    ```
#
# Let's go ahead and create our own module, with the following three types of elements:
#
# *   A variable `s`
# *   A function `say_hi()`
# *   A class `Greet`

# %%
# Contents of the module we are creating 
content = """
s = 'Hello ' 

def say_hi(name):
    print(s + name)

class Greet:
    pass
"""

# Write the above text to a file called my_module.py
# within our current working directory. 
with open('./my_module.py', 'w') as fp:
    fp.write(content)

# %% [markdown]
# This command writes (or saves) our module into our working directory so that we can use it again.

# %%
#Import the module we've just made! 
import my_module

# %% [markdown]
# Even though we've imported our module, note that its contents (the variables and functions we've defined within the module) are not directly accessible to us. As such, attempting to access these elements will result in (namespace) errors being thrown. We can safely see such errors using a `try-except` block:

# %%
try:
    # Try to print the variable s
    print(s)
except NameError:
    # We've caught a NameError exception (error!)
    # We inform the programmer (you) that the variable does not exist
    print("Variable 's' does not exist!")
# Out:
# Variable 's' does not exist!

# %% [markdown]
# Learning from this experience, it is important to know that objects in a module are only accessible when prefixed with via dot notation, as illustrated below.

# %%
# Accessing the variable s in my_module
my_module.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function in my_module
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %% [markdown]
# ### Example: Importing modules using an alias
# The `import` statement in Python also allows for the use of aliases when referencing a module. Using the `as` keyword, we can save ourselves from having to type otherwise long package names each time we need to access an object from a given module/package. This usually follows the following syntax:
#
# ```python
# import <module_name> as <new_model_name>
# ```
# or
#
# ```python
# from <package_name> import <module_name> as <new_model_name>
# ```
#
# For example:

# %%
# Alias for my_module
import my_module as md

# %% [markdown]
# We can thus treat the alias as the new name for the module.

# %%
# Accessing the variable s using an alias
md.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function using an alias for my_module
md.say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
# Accessing the empty class, Greet
md.Greet
# Out:
# my_module.Greet

# %% [markdown]
# ### Example: Importing modules directly
# Another way to access specific objects in a module is to use the `from` keyword and import them directly:
#
# ```python
# from <module_name> import <x, y, z>
# ```

# %%
from my_module import s, say_hi, Greet

# %%
s
# Out:
# 'Hello '

# %%
say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# We can see that using the `from xx import yy` structure provides access to the individual elements in the module without having to use dot notation. However, using aliases is the recommended way of importing modules and packages, as this prevents potential confusion when different modules contain functions or classes with the same name.
#
# To select all objects from a module we can use the following command, where the asterisk **( * )** *signifies all* :
#
# ```python
# from <module_name> import*
# ```
# Let's see this in practice one more time:

# %%
from my_module import *

# %% [markdown]
# Now we have access to all our module contents.

# %%
say_hi('Joanne')
# Out:
# Hello Joanne

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# ## Built-in modules
# Python contains a large number of what are known as 'built-in' modules. These modules can be accessed in Python programs by simply importing them using their name preceded by the keyword `import`.
#
# Each built-in module contains resources for certain system-specific functionalities such as operating system management, disk input-output, etc. Python scripts (with the **.py** extension) containing useful utilities are embedded within the standard library.
#
# To **display a list of all available modules**, use the following command:
#
# `help('modules')`

# %%
help('modules') # this might take a while
# Out:
# Please wait a moment while I gather a list of all available modules...
# c:\Users\horsh\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# c:\Users\horsh\anaconda3\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# c:\Users\horsh\anaconda3\Lib\pkgutil.py:78: UserWarning:
#
# The superqt.qtcompat module is deprecated as of v0.3.0. Please import from `qtpy` instead.
# 3204bda914b7f2c6f497__mypyc cmath               matplotlib          skimage
# IPython             cmd                 matplotlib_inline   sklearn
# OpenSSL             code                mccabe              sklearn_compat
# PIL                 codecs              mdit_py_plugins     slugify
# PyQt5               codeop              mdurl               smmap
# __future__          collections         menuinst            smtplib
# __hello__           colorama            mimetypes           sniffio
# __phello__          colorcet            mistune             snowballstemmer
# _abc                colorsys            mkl                 socket
# _aix_support        comm                mkl_fft             socketserver
# _android_support    commctrl            mkl_random          socks
# _apple_support      compileall          mmap                sockshandler
# _argon2_cffi_bindings concurrent          mmapfile            sortedcontainers
# _ast                conda               mmsystem            soupsieve
# _asyncio            conda_anaconda_telemetry modulefinder        sphinx
# _bisect             conda_anaconda_tos  more_itertools      spyder
# _black_version      conda_build         mpmath              spyder_kernels
# _blake2             conda_content_trust msgpack             sqlalchemy
# _brotli             conda_env           msvcrt              sqlite3
# _bz2                conda_index         multidict           sre_compile
# _cffi_backend       conda_libmamba_solver multipledispatch    sre_constants
# _codecs             conda_pack          multiprocessing     sre_parse
# _codecs_cn          conda_package_handling my_module           ssl
# _codecs_hk          conda_package_streaming mypy                sspi
# _codecs_iso2022     conda_token         mypy_extensions     sspicon
# _codecs_jp          configparser        mypyc               stack_data
# _codecs_kr          constantly          nacl                start_pythonwin
# _codecs_tw          contextlib          narwhals            stat
# _collections        contextvars         navigator_updater   statistics
# _collections_abc    contourpy           nbclient            statsmodels
# _colorize           cookiecutter        nbconvert           streamlit
# _compat_pickle      copy                nbformat            string
# _compression        copyreg             nest_asyncio        stringprep
# _contextvars        cpuinfo             netbios             struct
# _csv                cryptography        netrc               subprocess
# _ctypes             cssselect           networkx            superqt
# _ctypes_test        csv                 nltk                sympy
# _datetime           ctypes              notebook            symtable
# _decimal            curl                notebook_shim       sys
# _distutils_hack     curses              nt                  sysconfig
# _elementtree        cwp                 ntpath              tables
# _functools          cycler              ntsecuritycon       tabnanny
# _hashlib            cytoolz             nturl2path          tabulate
# _heapq              dask                numba               tarfile
# _imp                dask_expr           numbergen           tblib
# _interpchannels     dataclasses         numbers             tempfile
# _interpqueues       datashader          numexpr             tenacity
# _interpreters       datetime            numpy               terminado
# _io                 dateutil            numpydoc            test
# _ios_support        dbm                 odbc                test_pycosat
# _json               dde                 opcode              text_unidecode
# _locale             debugpy             openpyxl            textdistance
# _lsprof             decimal             operator            textwrap
# _lzma               decorator           optparse            this
# _markupbase         defusedxml          ordered_set         threading
# _md5                deprecated          os                  threadpoolctl
# _multibytecodec     diff_match_patch    overrides           three_merge
# _multiprocessing    difflib             packaging           tifffile
# _nsis               dill                pandas              time
# _opcode             dis                 pandocfilters       timeit
# _opcode_metadata    distributed         panel               timer
# _operator           distro              param               tinycss2
# _osx_support        docstring_to_markdown parsel              tkinter
# _overlapped         doctest             parso               tldextract
# _pickle             docutils            partd               tlz
# _plotly_future_     dotenv              pathlib             token
# _plotly_utils       email               pathspec            tokenize
# _py_abc             encodings           patsy               toml
# _pydatetime         ensurepip           pdb                 tomli
# _pydecimal          enum                perfmon             tomlkit
# _pyio               erfa                pexpect             tomllib
# _pylong             errno               pickle              toolz
# _pyrepl             et_xmlfile          pickleshare         tornado
# _pytest             evalidate           pickletools         tqdm
# _queue              executing           pip                 trace
# _random             fastjsonschema      pkce                traceback
# _ruamel_yaml        faulthandler        pkg_resources       tracemalloc
# _sha1               filecmp             pkginfo             traitlets
# _sha2               fileinput           pkgutil             truststore
# _sha3               filelock            platform            tty
# _signal             flake8              platformdirs        turtle
# _sitebuiltins       flask               plistlib            turtledemo
# _socket             fnmatch             plotly              twisted
# _sqlite3            fontTools           pluggy              typeguard
# _sre                fractions           ply                 typer
# _ssl                frozendict          poplib              types
# _stat               frozenlist          posixpath           typing
# _statistics         fsspec              poyo                typing_extensions
# _string             ftplib              pprint              tzdata
# _strptime           functools           profile             uc_micro
# _struct             gc                  prometheus_client   ujson
# _suggestions        genericpath         prompt_toolkit      unicodedata
# _symtable           getopt              propcache           unidecode
# _sysconfig          getpass             protego             unittest
# _system_path        gettext             pstats              urllib
# _testbuffer         git                 psutil              urllib3
# _testcapi           gitdb               pty                 uuid
# _testclinic         github              ptyprocess          venv
# _testclinic_limited glob                pure_eval           w3lib
# _testconsole        gmpy2               py                  warnings
# _testimportmultiple graphlib            py_compile          watchdog
# _testinternalcapi   greenlet            pyarrow             wave
# _testlimitedcapi    gzip                pyasn1              wcwidth
# _testmultiphase     h11                 pyasn1_modules      weakref
# _testsinglephase    h5py                pyclbr              webbrowser
# _thread             hashlib             pycodestyle         webencodings
# _threading_local    heapdict            pycosat             websocket
# _tkinter            heapq               pycparser           werkzeug
# _tokenize           hmac                pyct                whatthepatch
# _tracemalloc        holoviews           pycurl              wheel
# _typing             html                pydantic            widgetsnbextension
# _uuid               http                pydantic_core       win2kras
# _warnings           httpcore            pydantic_settings   win32api
# _weakref            httpx               pydispatch          win32clipboard
# _weakrefset         hvplot              pydoc               win32com
# _win32sysloader     hyperlink           pydoc_data          win32con
# _win32verstamp_pywin32ctypes idlelib             pydocstyle          win32console
# _winapi             idna                pyexpat             win32cred
# _winxptheme         imageio             pyflakes            win32crypt
# _wmi                imagesize           pygame              win32cryptcon
# _yaml               imaplib             pygments            win32ctypes
# _zoneinfo           imblearn            pylab               win32event
# abc                 importlib           pylint              win32evtlog
# adodbapi            importlib_metadata  pylint_venv         win32evtlogutil
# afxres              importlib_resources pyls_spyder         win32file
# aiobotocore         incremental         pylsp               win32gui
# aiohappyeyeballs    inflect             pylsp_black         win32gui_struct
# aiohttp             inflection          pylsp_jsonrpc       win32help
# aioitertools        iniconfig           pyodbc              win32inet
# aiosignal           inspect             pyparsing           win32inetcon
# alabaster           intake              pytest              win32job
# altair              intervaltree        pythoncom           win32lz
# anaconda_anon_usage io                  pythonjsonlogger    win32net
# anaconda_auth       ipaddress           pytoolconfig        win32netcon
# anaconda_catalogs   ipykernel           pytz                win32pdh
# anaconda_cli_base   ipykernel_launcher  pyuca               win32pdhquery
# anaconda_cloud_auth ipywidgets          pyviz_comms         win32pdhutil
# anaconda_navigator  isapi               pywin               win32pipe
# anaconda_project    isort               pywin32_bootstrap   win32print
# annotated_types     isympy              pywin32_testutil    win32process
# antigravity         itemadapter         pywintypes          win32profile
# anyio               itemloaders         pywt                win32ras
# appdirs             itertools           qdarkstyle          win32rcparser
# archspec            itsdangerous        qstylizer           win32security
# argon2              jedi                qtawesome           win32service
# argparse            jellyfish           qtconsole           win32serviceutil
# array               jinja2              qtpy                win32timezone
# arrow               jinja2_time         queue               win32trace
# ast                 jmespath            queuelib            win32traceutil
# astroid             joblib              quopri              win32transaction
# astropy             json                random              win32ts
# astropy_iers_data   json5               rasutil             win32ui
# asttokens           jsonpatch           re                  win32uiole
# async_lru           jsonpointer         readchar            win32verstamp
# asyncio             jsonschema          referencing         win32wnet
# asyncssh            jsonschema_specifications regcheck            win_inet_pton
# atexit              jupyter             regex               winerror
# atomicwrites        jupyter_client      regutil             winioctlcon
# attr                jupyter_console     repo_cli            winnt
# attrs               jupyter_core        reprlib             winperf
# autocommand         jupyter_events      requests            winpty
# automat             jupyter_lsp         requests_file       winreg
# autopep8            jupyter_server      requests_toolbelt   winsound
# babel               jupyter_server_terminals rfc3339_validator   winxpgui
# backports           jupyterlab          rfc3986_validator   winxptheme
# base64              jupyterlab_plotly   rich                wrapt
# bcrypt              jupyterlab_pygments rlcompleter         wsgiref
# bdb                 jupyterlab_server   roman_numerals      xarray
# binaryornot         jupyterlab_widgets  rope                xlwings
# binascii            jwt                 rpds                xlwingsjs
# binstar_client      keyring             rtree               xml
# bisect              keyword             ruamel_yaml         xmlrpc
# black               kiwisolver          runpy               xxlimited
# blackd              lazy_loader         s3fs                xxlimited_35
# bleach              lckr_jupyterlab_variableinspector sched               xxsubtype
# blib2to3            libarchive          scipy               xyzservices
# blinker             libmambapy          scrapy              yaml
# bokeh               lief                seaborn             yapf
# boltons             linecache           secrets             yapf_third_party
# botocore            linkify_it          select              yapftests
# bottleneck          llvmlite            selectors           yarl
# brotli              lmdb                semver              zict
# bs4                 locale              send2trash          zipapp
# builtins            locket              service_identity    zipfile
# bz2                 logging             servicemanager      zipimport
# cProfile            lxml                setuptools          zipp
# cachetools          lz4                 shellingham         zlib
# calendar            lzma                shelve              zmq
# certifi             mailbox             shlex               zoneinfo
# cffi                markdown            shutil              zope
# chardet             markdown_it         signal              zstandard
# charset_normalizer  markupsafe          sipbuild
# click               marshal             site
# cloudpickle         math                six
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %% [markdown]
# Alternatively, the `dir()` function is a built-in function that can be used to **list all the function names (or variable names) in a module**:
#
# `dir(module_name)`

# %%
# Import math module 
import math 

# Use the sqrt function in the math module
x = math.sqrt(81)
print('The square root of 81 is equal to {}'.format(x))

# List all functions in math module 
list_all= dir(math)
print('Functions in the math module: {}'.format(list_all))
# Out:
# The square root of 81 is equal to 9.0
# Functions in the math module: ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# ## Summary
#
# In this train, we learned how to create, import, and use modules. We also explored the use of built-in modules in Python and how to determine what functions are present within modules.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:140px";/>
# </div>
